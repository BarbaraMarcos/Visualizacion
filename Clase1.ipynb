# %% [markdown]
# ## Clase 1 - Introducción a Python

# %%
print('hola')
# Out:
# hola

# %%
import numpy as np

# %%
x = 50
y = np.random.rand(x)
y
# Out:
# array([0.45098302, 0.24515494, 0.32585354, 0.33424958, 0.74673528,
#        0.1717534 , 0.02056921, 0.81521508, 0.06700614, 0.5523742 ,
#        0.83877667, 0.05495988, 0.09100865, 0.19935289, 0.80594927,
#        0.78826952, 0.35114007, 0.31851549, 0.88130128, 0.32839739,
#        0.56174002, 0.87309625, 0.97776928, 0.62573491, 0.91511339,
#        0.1571498 , 0.76741834, 0.47785423, 0.04016719, 0.1037259 ,
#        0.34189582, 0.45726897, 0.67516011, 0.01486575, 0.10898754,
#        0.27889894, 0.58127502, 0.52183656, 0.87228271, 0.14731958,
#        0.2684439 , 0.89816971, 0.27595815, 0.84639057, 0.5347101 ,
#        0.29618159, 0.26369054, 0.28041239, 0.59864607, 0.85637691])

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %% [markdown]
# ## Tipos de datos

# %%
import math

# %%
type(4)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
type(-3)
# Out:
# int

# %%
x = 'nombre1'
x
# Out:
# 'nombre1'

# %%
type(x)
# Out:
# str

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
numbers[0]
# Out:
# 1

# %%
numbers[4]
# Out:
# 5

# %%
sum_numbers = sum(numbers)
sum_numbers
# Out:
# 15

# %%
sum(numbers)
# Out:
# 15

# %%
len(numbers)
# Out:
# 5

# %%
length = len(numbers)
length
# Out:
# 5

# %%
promedio = sum_/length
promedio
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_117/346640476.py in <module>
# ----> 1 promedio = sum_/length
#       2 promedio
#
# NameError: name 'sum_' is not defined

# %%
promedio = sum_numbers/length
promedio
# Out:
# 3.0

# %%
type(3/5)
# Out:
# float

# %%
type(math.pi)
# Out:
# float

# %%
type('math.pi')
# Out:
# str

# %%
type(False)
# Out:
# bool

# %%
type('True')
# Out:
# str

# %%
print(None)
# Out:
# None

# %%
type(None)
# Out:
# NoneType

# %%
x = 16
y = 8
if x < y:
    print('{} es menor que {}'.format(x,y))
else:
    print(x, 'es mayor que', y)
# Out:
# 16 es mayor que 8

# %%
unalista = [True, 6<5, 1==3, None is None]

# %%
unalista
# Out:
# [True, False, False, True]

# %% [markdown]
# ## El uso de for loop

# %%
for element in unalista:
    print(element,'\t',type(element))
# Out:
# True 	 <class 'bool'>
# False 	 <class 'bool'>
# False 	 <class 'bool'>
# True 	 <class 'bool'>

# %% [markdown]
# ## Lista

# %%
unalista = ['first','second','third','fourth','fifth','sixth']
unalista
# Out:
# ['first', 'second', 'third', 'fourth', 'fifth', 'sixth']

# %%
unalista[:2]
# Out:
# ['first', 'second']

# %%
unalista[:]
# Out:
# ['first', 'second', 'third', 'fourth', 'fifth', 'sixth']

# %%
unalista[1:3]
# Out:
# ['second', 'third']

# %%
unalista[5]
# Out:
# 'sixth'

# %%
unalista[-1]
# Out:
# 'sixth'

# %%
unalista[-3:-1]
# Out:
# ['fourth', 'fifth']
